# %% [markdown]
# ### Pandas concat()
#
# ### What is concat()?
#
# concat() is used to combine multiple DataFrames or Series along rows or columns.
#
# Think of it as stacking data (unlike merge() which matches keys).
#
# ##### Basic Syntax
#
# pd.concat(
#     objs,
#     axis=0,
#     join='outer',
#     ignore_index=False,
#     keys=None,
#     levels=None,
#     names=None,
#     verify_integrity=False,
#     sort=False,
#     copy=True
# )
#
# Parameters Explained One by One
#
# ### 1.objs
#
# A list or dictionary of DataFrames/Series to combine.
#
# e.g
#
# pd.concat([df1, df2])
#
# Mandatory parameter

# %%
# Example

import pandas as pd

# First DataFrame
df1 = pd.DataFrame({
    'Name': ['Ali', 'Sara'],
    'Department': ['HR', 'IT']
})

# Second DataFrame
df2 = pd.DataFrame({
    'Name': ['John', 'Ayesha'],
    'Department': ['Finance', 'Marketing']
})

# Concatenate
result = pd.concat([df1, df2])

print(result)
# Out:
#      Name Department
# 0     Ali         HR
# 1    Sara         IT
# 0    John    Finance
# 1  Ayesha  Marketing

# %% [markdown]
# ### 2.axis
#
# Defines direction of concatenation.
#
# axis=0  # Row-wise (default)
#
# axis=1  # Column-wise
#
# e.g
#
# pd.concat([df1, df2], axis=0)  # stack rows
#
# pd.concat([df1, df2], axis=1)  # add columns

# %% [markdown]
# ### 1. pd.concat([df1, df2], axis=0) → Stack Rows (Vertical Concatenation)
#
# • axis=0 means concatenate row-wise (default).
#
# • It places df2 below df1, creating a longer DataFrame.

# %%
# Example
import pandas as pd

df1 = pd.DataFrame({
    'Name': ['Ali', 'Sara'],
    'Department': ['HR', 'IT']
})

df2 = pd.DataFrame({
    'Name': ['John', 'Ayesha'],
    'Department': ['Finance', 'Marketing']
})

result = pd.concat([df1, df2], axis=0)
print(result)
# Out:
#      Name Department
# 0     Ali         HR
# 1    Sara         IT
# 0    John    Finance
# 1  Ayesha  Marketing

# %% [markdown]
# ### 2. pd.concat([df1, df2], axis=1) → Add Columns (Horizontal Concatenation)
#
# • axis=1 means concatenate column-wise.
#
# • It places df2 next to df1, creating a wider DataFrame.

# %%
result = pd.concat([df1, df2], axis=1)
print(result)
# Out:
#    Name Department    Name Department
# 0   Ali         HR    John    Finance
# 1  Sara         IT  Ayesha  Marketing

# %% [markdown]
# ### 3.join
#
# How to handle non-matching columns.
#
# join='outer'  # default (union)
#
# join='inner'  # intersection
#
# e.g
#
# pd.concat([df1, df2], join='inner')
#
# Important for datasets with different columns.

# %%
# Example
import pandas as pd

df1 = pd.DataFrame({
    'Name': ['Ali', 'Sara'],
    'Department': ['HR', 'IT'],
    'Salary': [40000, 50000]
})

df2 = pd.DataFrame({
    'Name': ['John', 'Ayesha'],
    'Department': ['Finance', 'Marketing'],
    'Age': [30, 28]
})

# Concatenate with inner join
result = pd.concat([df1, df2], join='inner', axis=0)

print(result)
# Out:
#      Name Department
# 0     Ali         HR
# 1    Sara         IT
# 0    John    Finance
# 1  Ayesha  Marketing

# %%
# If You Use join='outer'
pd.concat([df1, df2], join='outer', axis=0)
#  Keeps all columns (Name, Department, Salary, Age) and fills missing values with NaN.
# Out:
#      Name Department   Salary   Age
# 0     Ali         HR  40000.0   NaN
# 1    Sara         IT  50000.0   NaN
# 0    John    Finance      NaN  30.0
# 1  Ayesha  Marketing      NaN  28.0

# %% [markdown]
# ### 4.ignore_index
#
# Resets index in the result.
#
# ignore_index=True
#
# e.g
#
# pd.concat([df1, df2], ignore_index=True)
#
# Recommended for clean datasets & exports

# %%
# Example

import pandas as pd

df1 = pd.DataFrame({
    'Name': ['Ali', 'Sara'],
    'Department': ['HR', 'IT']
})

df2 = pd.DataFrame({
    'Name': ['John', 'Ayesha'],
    'Department': ['Finance', 'Marketing']
})

# Concatenate with ignore_index
result = pd.concat([df1, df2], ignore_index=True)

print(result)
# Out:
#      Name Department
# 0     Ali         HR
# 1    Sara         IT
# 2    John    Finance
# 3  Ayesha  Marketing

# %% [markdown]
# ### 5.keys
#
# Adds a hierarchical index to identify data source.
#
# pd.concat([df1, df2], keys=['Jan', 'Feb'])
#
#
# Useful for time-based or multi-source projects

# %%
# Example
import pandas as pd

df1 = pd.DataFrame({
    'Name': ['Ali', 'Sara'],
    'Department': ['HR', 'IT']
})

df2 = pd.DataFrame({
    'Name': ['John', 'Ayesha'],
    'Department': ['Finance', 'Marketing']
})

# Concatenate with keys
result = pd.concat([df1, df2], keys=['Jan', 'Feb'])

print(result)
# Out:
#          Name Department
# Jan 0     Ali         HR
#     1    Sara         IT
# Feb 0    John    Finance
#     1  Ayesha  Marketing

# %% [markdown]
# ### 6.levels
#
# Defines levels for MultiIndex (advanced).
#
# pd.concat([df1, df2], levels=[['A', 'B']])
#
# Rarely used in beginner projects.

# %%
# Example
import pandas as pd

df1 = pd.DataFrame({
    'Name': ['Ali', 'Sara'],
    'Department': ['HR', 'IT']
})

df2 = pd.DataFrame({
    'Name': ['John', 'Ayesha'],
    'Department': ['Finance', 'Marketing']
})

# Concatenate with keys and levels
result = pd.concat([df1, df2], keys=['A', 'B'], levels=[['A', 'B']])

print(result)
# Out:
#        Name Department
# A 0     Ali         HR
#   1    Sara         IT
# B 0    John    Finance
#   1  Ayesha  Marketing

# %% [markdown]
# ### 7.names
#
# Names of MultiIndex levels.
#
# pd.concat([df1, df2], keys=['2024', '2025'], names=['Year'])
#
# Improves readability.

# %%
# Example
import pandas as pd

df1 = pd.DataFrame({
    'Name': ['Ali', 'Sara'],
    'Department': ['HR', 'IT']
})

df2 = pd.DataFrame({
    'Name': ['John', 'Ayesha'],
    'Department': ['Finance', 'Marketing']
})

# Concatenate with keys and names
result = pd.concat([df1, df2], keys=['2024', '2025'], names=['Year'])

print(result)
# Out:
#           Name Department
# Year
# 2024 0     Ali         HR
#      1    Sara         IT
# 2025 0    John    Finance
#      1  Ayesha  Marketing

# %% [markdown]
# ### 8.verify_integrity
#
# Checks for duplicate indexes.
#
# verify_integrity=True
#
# Raises error if duplicate index exists.

# %%
# Example 1: No Duplicate Index (Works Fine)
import pandas as pd

df1 = pd.DataFrame({'Name': ['Ali', 'Sara']}, index=[0, 1])
df2 = pd.DataFrame({'Name': ['John', 'Ayesha']}, index=[2, 3])

result = pd.concat([df1, df2], verify_integrity=True)
print(result)
# Out:
#      Name
# 0     Ali
# 1    Sara
# 2    John
# 3  Ayesha

# %%
# Example 2: Duplicate Index (Error Raised)
df1 = pd.DataFrame({'Name': ['Ali', 'Sara']}, index=[0, 1])
df2 = pd.DataFrame({'Name': ['John', 'Ayesha']}, index=[0, 1])

# This will raise an error
result = pd.concat([df1, df2], verify_integrity= True)
result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-533264558.py in <cell line: 0>()
#       4
#       5 # This will raise an error
# ----> 6 result = pd.concat([df1, df2], verify_integrity= True)
#       7 result
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     393     )
#     394
# --> 395     return op.get_result()
#     396
#     397
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     669             for obj in self.objs:
#     670                 indexers = {}
# --> 671                 for ax, new_labels in enumerate(self.new_axes):
#     672                     # ::-1 to convert BlockManager ax to DataFrame ax
#     673                     if ax == self.bm_axis:
#
# properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in new_axes(self)
#     701         ndim = self._get_result_dim()
#     702         return [
# --> 703             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     704             for i in range(ndim)
#     705         ]
#
# properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     764             )
#     765
# --> 766         self._maybe_check_integrity(concat_axis)
#     767
#     768         return concat_axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in _maybe_check_integrity(self, concat_index)
#     772             if not concat_index.is_unique:
#     773                 overlap = concat_index[concat_index.duplicated()].unique()
# --> 774                 raise ValueError(f"Indexes have overlapping values: {overlap}")
#     775
#     776
#
# ValueError: Indexes have overlapping values: Index([0, 1], dtype='int64')

# %% [markdown]
# ### 9.sort
#
# Sorts non-matching columns.
#
# sort=False  # default
# sort=True
#
# Keep False for better performance.

# %%
# Example

import pandas as pd

df1 = pd.DataFrame({
    'Name': ['Ali', 'Sara'],
    'Department': ['HR', 'IT']
})

df2 = pd.DataFrame({
    'Age': [25, 30],
    'Name': ['John', 'Ayesha']
})

# Concatenate with sort=False (default)
result1 = pd.concat([df1, df2], sort=False)

# Concatenate with sort=True
result2 = pd.concat([df1, df2], sort=True)

print("sort=False:\n", result1, "\n")
print("sort=True:\n", result2)
# Out:
# sort=False:
#       Name Department   Age
# 0     Ali         HR   NaN
# 1    Sara         IT   NaN
# 0    John        NaN  25.0
# 1  Ayesha        NaN  30.0
#
# sort=True:
#      Age Department    Name
# 0   NaN         HR     Ali
# 1   NaN         IT    Sara
# 0  25.0        NaN    John
# 1  30.0        NaN  Ayesha

# %% [markdown]
# ### 10.copy
#
# Controls data copying.
#
# copy=True  # default
#
# Usually left unchanged.

# %%
# Example 1: With copy=True (Safe Copy)
import pandas as pd

df1 = pd.DataFrame({'A': [1, 2, 3]})

# Create a copy
df2 = pd.DataFrame(df1, copy=True)

# Modify df2
df2.loc[0, 'A'] = 100

print("df1:\n", df1)
print("df2:\n", df2)
# Out:
# df1:
#     A
# 0  1
# 1  2
# 2  3
# df2:
#       A
# 0  100
# 1    2
# 2    3

# %%
# Example 2: With copy=False (Shared Reference)
df1 = pd.DataFrame({'A': [1, 2, 3]})

# Try to avoid copying
df2 = pd.DataFrame(df1, copy=False)

# Modify df2
df2.loc[0, 'A'] = 100

print("df1:\n", df1)
print("df2:\n", df2)
# Out:
# df1:
#       A
# 0  100
# 1    2
# 2    3
# df2:
#       A
# 0  100
# 1    2
# 2    3

# %%
# Row-Wise Concatenation
# pd.concat([df1, df2], ignore_index=True)
import pandas as pd

df1 = pd.DataFrame({'Name': ['Ali', 'Sara']})
df2 = pd.DataFrame({'Name': ['John', 'Ayesha']})

result = pd.concat([df1, df2], ignore_index=True)
print(result)
# Out:
#      Name
# 0     Ali
# 1    Sara
# 2    John
# 3  Ayesha

# %%
# Column-Wise Concatenation
pd.concat([df1, df2], axis=1)
# Out:
#    Name    Name
# 0   Ali    John
# 1  Sara  Ayesha

# %%
# Inner Join Concatenation
pd.concat([df1, df2], join='inner')
# Out:
#      Name
# 0     Ali
# 1    Sara
# 0    John
# 1  Ayesha

# %%
# Identify Source Using Keys
pd.concat(
    [df1, df2],
    keys=['Source1', 'Source2'],
    names=['DataSource']
)
# Out:
#                 Name
# DataSource
# Source1    0     Ali
#            1    Sara
# Source2    0    John
#            1  Ayesha
